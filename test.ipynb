# %%
print("test")
# Out:
# test

# %%
import requests

API_URL = "https://api-inference.huggingface.co/models/runwayml/stable-diffusion-v1-5"
headers = {"Authorization": "Bearer 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"}

def query(payload):
	response = requests.post(API_URL, headers=headers, json=payload)
	return response.content
image_bytes = query({
	"inputs": "Astronaut riding a horse",
})
# You can access the image with PIL.Image for example
import io
from PIL import Image
image = Image.open(io.BytesIO(image_bytes))
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# Cell In[9], line 15
#      13 import io
#      14 from PIL import Image
# ---> 15 image = Image.open(io.BytesIO(image_bytes))
#
# File ~/.local/lib/python3.10/site-packages/PIL/Image.py:3298, in open(fp, mode, formats)
#    3296     warnings.warn(message)
#    3297 msg = "cannot identify image file %r" % (filename if filename else fp)
# -> 3298 raise UnidentifiedImageError(msg)
#
# UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x7fe63044c680>

# %%
import requests

API_URL = "https://api-inference.huggingface.co/models/runwayml/stable-diffusion-v1-5"
headers = {"Authorization": "Bearer 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"}

def query(payload):
	response = requests.post(API_URL, headers=headers, json=payload)
	return response.content
image_bytes = query({
	"inputs": "Astronaut riding a horse",
})
# You can access the image with PIL.Image for example
import io
from PIL import Image
image = Image.open(io.BytesIO(image_bytes))

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>
